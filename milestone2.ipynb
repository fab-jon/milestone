# %% [markdown]
# ## Fabiolah Jones
# ## 8/5/2025
# ## Milestone #3

# %% [markdown]
# ## Dataset Analysis

# %%
import pandas as pd
datafile = pd.read_csv("Perceptions_Of_School_Safety.csv")

# %% [markdown]
# ### Using .info() we get an overview of the amount of rows/columns and the datatype of the vaules

# %%
datafile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Columns: 154 entries, OBJECTID to Shape__Length
# dtypes: float64(152), int64(1), object(1)
# memory usage: 304.5+ KB

# %% [markdown]
# ### The dataset as 253 rows and 154 columns

# %%
datafile.shape
# Out:
# (253, 154)

# %% [markdown]
# ### Using .describe() to obtain the statistical summary of the dataset

# %%
datafile.describe()
# Out:
#          OBJECTID  Percent_of_7th_Graders_Who_Felt  \
# count  253.000000                       172.000000
# mean   127.000000                         0.241407
# std     73.179004                         0.076650
# min      1.000000                         0.073000
# 25%     64.000000                         0.188500
# 50%    127.000000                         0.234000
# 75%    190.000000                         0.292500
# max    253.000000                         0.490000
#
#        Percent_of_7th_Graders_Who_Fe_1  Percent_of_7th_Graders_Who_Fe_2  \
# count                       172.000000                       172.000000
# mean                          0.445134                         0.241023
# std                           0.045504                         0.068565
# min                           0.296000                         0.094000
# 25%                           0.417000                         0.194000
# ...

# %% [markdown]
# ### The names of all the columns are as follows:

# %%
datafile.columns
# Out:
# Index(['OBJECTID', 'NAME', 'Percent_of_7th_Graders_Who_Felt',
#        'Percent_of_7th_Graders_Who_Fe_1', 'Percent_of_7th_Graders_Who_Fe_2',
#        'Percent_of_7th_Graders_Who_Fe_3', 'Percent_of_7th_Graders_Who_Fe_4',
#        'Percent_of_9th_Graders_Who_Felt', 'Percent_of_9th_Graders_Who_Fe_1',
#        'Percent_of_9th_Graders_Who_Fe_2',
#        ...
#        'Percent_of_Straight_Students__2', 'Percent_of_Straight_Students__3',
#        'Percent_of_Straight_Students__4', 'Percent_of_Students_Who_Are_Not',
#        'Percent_of_Students_Who_Are_N_1', 'Percent_of_Students_Who_Are_N_2',
#        'Percent_of_Students_Who_Are_N_3', 'Percent_of_Students_Who_Are_N_4',
#        'Shape__Area', 'Shape__Length'],
#       dtype='object', length=154)

# %% [markdown]
# ### Every value in the dataset is a decimal therefore they datatype that will result for each column is float

# %%
datafile.dtypes
# Out:
# OBJECTID                             int64
# NAME                                object
# Percent_of_7th_Graders_Who_Felt    float64
# Percent_of_7th_Graders_Who_Fe_1    float64
# Percent_of_7th_Graders_Who_Fe_2    float64
#                                     ...
# Percent_of_Students_Who_Are_N_2    float64
# Percent_of_Students_Who_Are_N_3    float64
# Percent_of_Students_Who_Are_N_4    float64
# Shape__Area                        float64
# Shape__Length                      float64
# Length: 154, dtype: object

# %% [markdown]
# ### The beginning 5 rows and last 5 rows of are displayed below:

# %%
datafile.head()
# Out:
#    OBJECTID                                          NAME  \
# 0         1               Taft Union High School District
# 1         2      Chaffey Joint Union High School District
# 2         3    Porterville Unified (9-12) School District
# 3         4    William S. Hart Union High School District
# 4         5  Santa Ynez Valley Union High School District
#
#    Percent_of_7th_Graders_Who_Felt  Percent_of_7th_Graders_Who_Fe_1  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    Percent_of_7th_Graders_Who_Fe_2  Percent_of_7th_Graders_Who_Fe_3  \
# 0                              NaN                              NaN
# ...

# %%
datafile.tail()
# Out:
#      OBJECTID                                  NAME  \
# 248       249  Palm Springs Unified School District
# 249       250  Corona-Norco Unified School District
# 250       251   Temple City Unified School District
# 251       252       Arcadia Unified School District
# 252       253    Bellflower Unified School District
#
#      Percent_of_7th_Graders_Who_Felt  Percent_of_7th_Graders_Who_Fe_1  \
# 248                            0.197                            0.468
# 249                            0.339                            0.439
# 250                              NaN                              NaN
# 251                            0.360                            0.464
# 252                            0.115                            0.440
#
#      Percent_of_7th_Graders_Who_Fe_2  Percent_of_7th_Graders_Who_Fe_3  \
# 248                            0.255                            0.048
# 249                            0.170                            0.034
# ...

# %% [markdown]
# ### A random row from the dataset is displayed with .sample()

# %%
datafile.sample()
# Out:
#      OBJECTID                                   NAME  \
# 135       136  Sweetwater Union High School District
#
#      Percent_of_7th_Graders_Who_Felt  Percent_of_7th_Graders_Who_Fe_1  \
# 135                            0.214                             0.43
#
#      Percent_of_7th_Graders_Who_Fe_2  Percent_of_7th_Graders_Who_Fe_3  \
# 135                            0.276                            0.047
#
#      Percent_of_7th_Graders_Who_Fe_4  Percent_of_9th_Graders_Who_Felt  \
# 135                            0.033                            0.153
#
#      Percent_of_9th_Graders_Who_Fe_1  Percent_of_9th_Graders_Who_Fe_2  ...  \
# 135                            0.436                            0.339  ...
#
#      Percent_of_Straight_Students__2  Percent_of_Straight_Students__3  \
# 135                            0.302                            0.035
#
#      Percent_of_Straight_Students__4  Percent_of_Students_Who_Are_Not  \
# ...
